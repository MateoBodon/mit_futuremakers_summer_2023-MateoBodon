# %% [markdown]
# <a href="https://colab.research.google.com/github/MySureStart/mit_futuremakers_summer_2023-MateoBodon/blob/main/Module_12_Regularization/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Objective
# * To acquaint you with the problem of overfit models and to mitigate it with regularization

# %%
# Basic packages
import pandas as pd
import numpy as np
import re
import collections
import matplotlib.pyplot as plt
from pathlib import Path

# Packages for data preparation
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder

import nltk
nltk.download('stopwords')

# Packages for modeling
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

NB_WORDS = 10000  # Parameter indicating the number of words we'll put in the dictionary
NB_START_EPOCHS = 20  # Number of epochs we usually start to train with
BATCH_SIZE = 512  # Size of the batches used in the mini-batch gradient descent
MAX_LEN = 20  # Maximum number of words in a sequence

root = Path('../content/')
input_path = root / 'input/'
ouput_path = root / 'output/'
source_path = root / 'source/'

def deep_model(model, X_train, y_train, X_valid, y_valid):
    model.compile(optimizer='rmsprop'
                  , loss='categorical_crossentropy'
                  , metrics=['accuracy'])

    history = model.fit(X_train
                       , y_train
                       , epochs=NB_START_EPOCHS
                       , batch_size=BATCH_SIZE
                       , validation_data=(X_valid, y_valid)
                       , verbose=1)
    return history

def eval_metric(model, history, metric_name):
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]

    e = range(1, NB_START_EPOCHS + 1)

    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    plt.show()

def remove_stopwords(input_text):
    stopwords_list = stopwords.words('english')
    # Some words which might indicate a certain sentiment are kept via a whitelist
    whitelist = ["n't", "not", "no"]
    words = input_text.split()
    clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1]
    return " ".join(clean_words)

def remove_mentions(input_text):
    return re.sub(r'@\w+', '', input_text)

def test_model(model, X_train, y_train, X_test, y_test, epoch_stop):
    model.fit(X_train
              , y_train
              , epochs=epoch_stop
              , batch_size=BATCH_SIZE
              , verbose=1)
    results = model.evaluate(X_test, y_test)
    print()
    print('Test accuracy: {0:.2f}%'.format(results[1]*100))
    return results

def compare_models_by_metric(model_1, model_2, model_hist_1, model_hist_2, metric):
    metric_model_1 = model_hist_1.history[metric]
    metric_model_2 = model_hist_2.history[metric]

    e = range(1, NB_START_EPOCHS + 1)

    metrics_dict = {
        'acc' : 'Training Accuracy',
        'loss' : 'Training Loss',
        'val_acc' : 'Validation accuracy',
        'val_loss' : 'Validation loss'
    }

    metric_label = metrics_dict[metric]

    plt.plot(e, metric_model_1, 'bo', label=model_1.name)
    plt.plot(e, metric_model_2, 'b', label=model_2.name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_label)
    plt.title('Comparing ' + metric_label + ' between models')
    plt.legend()
    plt.show()

def optimal_epoch(model_hist):
    min_epoch = np.argmin(model_hist.history['val_loss']) + 1
    print("Minimum validation loss reached in epoch {}".format(min_epoch))
    return min_epoch

! gdown --id 1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
! mkdir input/
! mv Tweets.csv input/

df = pd.read_csv(input_path / 'Tweets.csv')
df = df.reindex(np.random.permutation(df.index))
df = df[['text', 'airline_sentiment']]
df.text = df.text.apply(remove_stopwords).apply(remove_mentions)

X_train, X_test, y_train, y_test = train_test_split(df.text, df.airline_sentiment, test_size=0.1, random_state=37)

tk = Tokenizer(num_words=NB_WORDS,
               filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~\t\n',
               lower=True,
               char_level=False,
               split=' ')
tk.fit_on_texts(X_train)

X_train_oh = tk.texts_to_matrix(X_train, mode='binary')
X_test_oh = tk.texts_to_matrix(X_test, mode='binary')

le = LabelEncoder()
y_train_le = le.fit_transform(y_train)
y_test_le = le.transform(y_test)
y_train_oh = to_categorical(y_train_le)
y_test_oh = to_categorical(y_test_le)

X_train_rest, X_valid, y_train_rest, y_valid = train_test_split(X_train_oh, y_train_oh, test_size=0.1, random_state=37)

base_model = models.Sequential()
base_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
base_model.add(layers.Dense(64, activation='relu'))
base_model.add(layers.Dense(3, activation='softmax'))
base_history = deep_model(base_model, X_train_rest, y_train_rest, X_valid, y_valid)
base_min = optimal_epoch(base_history)

reduced_model = models.Sequential()
reduced_model.add(layers.Dense(16, activation='relu', input_shape=(NB_WORDS,)))
reduced_model.add(layers.Dense(3, activation='softmax'))
reduced_history = deep_model(reduced_model, X_train_rest, y_train_rest, X_valid, y_valid)
reduced_min = optimal_epoch(reduced_history)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
# To: /content/Tweets.csv
# 100% 3.42M/3.42M [00:00<00:00, 38.5MB/s]
# Epoch 1/20
# 24/24 [==============================] - 4s 83ms/step - loss: 0.8744 - accuracy: 0.6180 - val_loss: 0.7487 - val_accuracy: 0.6351
# Epoch 2/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.6451 - accuracy: 0.7165 - val_loss: 0.6146 - val_accuracy: 0.7663
# Epoch 3/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.5027 - accuracy: 0.8192 - val_loss: 0.5369 - val_accuracy: 0.7944
# Epoch 4/20
# 24/24 [==============================] - 2s 69ms/step - loss: 0.4071 - accuracy: 0.8590 - val_loss: 0.5172 - val_accuracy: 0.8020
# Epoch 5/20
# 24/24 [==============================] - 2s 91ms/step - loss: 0.3437 - accuracy: 0.8813 - val_loss: 0.5132 - val_accuracy: 0.8058
# Epoch 6/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.2945 - accuracy: 0.8980 - val_loss: 0.5167 - val_accuracy: 0.8179
# Epoch 7/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.2521 - accuracy: 0.9125 - val_loss: 0.5438 - val_accuracy: 0.8073
# Epoch 8/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.2184 - accuracy: 0.9255 - val_loss: 0.5687 - val_accuracy: 0.8171
# Epoch 9/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.1882 - accuracy: 0.9377 - val_loss: 0.5896 - val_accuracy: 0.8164
# Epoch 10/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.1626 - accuracy: 0.9475 - val_loss: 0.6221 - val_accuracy: 0.8012
# Epoch 11/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.1387 - accuracy: 0.9555 - val_loss: 0.6637 - val_accuracy: 0.8012
# Epoch 12/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.1216 - accuracy: 0.9630 - val_loss: 0.7005 - val_accuracy: 0.8058
# Epoch 13/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.1056 - accuracy: 0.9680 - val_loss: 0.7412 - val_accuracy: 0.7982
# Epoch 14/20
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0923 - accuracy: 0.9718 - val_loss: 0.7729 - val_accuracy: 0.7929
# Epoch 15/20
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0813 - accuracy: 0.9760 - val_loss: 0.8160 - val_accuracy: 0.7853
# Epoch 16/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0721 - accuracy: 0.9792 - val_loss: 0.8524 - val_accuracy: 0.7838
# Epoch 17/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0647 - accuracy: 0.9806 - val_loss: 0.9001 - val_accuracy: 0.7914
# Epoch 18/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0571 - accuracy: 0.9825 - val_loss: 0.9379 - val_accuracy: 0.7724
# Epoch 19/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0520 - accuracy: 0.9843 - val_loss: 0.9666 - val_accuracy: 0.7868
# Epoch 20/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0474 - accuracy: 0.9856 - val_loss: 1.0110 - val_accuracy: 0.7671
# Minimum validation loss reached in epoch 5
# Epoch 1/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.9688 - accuracy: 0.6251 - val_loss: 0.8728 - val_accuracy: 0.6275
# Epoch 2/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.7978 - accuracy: 0.6459 - val_loss: 0.7706 - val_accuracy: 0.6419
# Epoch 3/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.7076 - accuracy: 0.6725 - val_loss: 0.7107 - val_accuracy: 0.6813
# Epoch 4/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6453 - accuracy: 0.7131 - val_loss: 0.6657 - val_accuracy: 0.7276
# Epoch 5/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.5943 - accuracy: 0.7569 - val_loss: 0.6279 - val_accuracy: 0.7564
# Epoch 6/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.5515 - accuracy: 0.7950 - val_loss: 0.5986 - val_accuracy: 0.7724
# Epoch 7/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.5147 - accuracy: 0.8184 - val_loss: 0.5746 - val_accuracy: 0.7898
# Epoch 8/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.4829 - accuracy: 0.8337 - val_loss: 0.5541 - val_accuracy: 0.8005
# Epoch 9/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.4545 - accuracy: 0.8470 - val_loss: 0.5387 - val_accuracy: 0.8012
# Epoch 10/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.4295 - accuracy: 0.8579 - val_loss: 0.5252 - val_accuracy: 0.8103
# Epoch 11/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.4075 - accuracy: 0.8666 - val_loss: 0.5166 - val_accuracy: 0.8149
# Epoch 12/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.3883 - accuracy: 0.8722 - val_loss: 0.5096 - val_accuracy: 0.8156
# Epoch 13/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.3704 - accuracy: 0.8784 - val_loss: 0.5039 - val_accuracy: 0.8171
# Epoch 14/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.3541 - accuracy: 0.8833 - val_loss: 0.5010 - val_accuracy: 0.8179
# Epoch 15/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.3398 - accuracy: 0.8879 - val_loss: 0.4982 - val_accuracy: 0.8202
# Epoch 16/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.3264 - accuracy: 0.8929 - val_loss: 0.4989 - val_accuracy: 0.8179
# Epoch 17/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.3141 - accuracy: 0.8960 - val_loss: 0.4986 - val_accuracy: 0.8187
# Epoch 18/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.3026 - accuracy: 0.9001 - val_loss: 0.4986 - val_accuracy: 0.8179
# Epoch 19/20
# 24/24 [==============================] - 1s 34ms/step - loss: 0.2918 - accuracy: 0.9045 - val_loss: 0.5013 - val_accuracy: 0.8179
# Epoch 20/20
# 24/24 [==============================] - 1s 44ms/step - loss: 0.2817 - accuracy: 0.9075 - val_loss: 0.5031 - val_accuracy: 0.8156
# Minimum validation loss reached in epoch 15

# %% [markdown]
# # Applying regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization pushes weights towards exactly zero encouraging a sparse model. L2 regularization will penalize the weights parameters without making them sparse since the penalty goes to zero for small weights-one reason why L2 is more common.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
reg_model = models.Sequential()
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(NB_WORDS,)))
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu'))
reg_model.add(layers.Dense(3, activation='softmax'))
reg_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                640064
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
reg_history = deep_model(reg_model, X_train_rest, y_train_rest, X_valid, y_valid)
reg_min = optimal_epoch(reg_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 3s 106ms/step - loss: 1.0332 - accuracy: 0.6310 - val_loss: 0.9107 - val_accuracy: 0.6290
# Epoch 2/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.8126 - accuracy: 0.6955 - val_loss: 0.7736 - val_accuracy: 0.7473
# Epoch 3/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.6777 - accuracy: 0.7949 - val_loss: 0.6851 - val_accuracy: 0.7891
# Epoch 4/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.5752 - accuracy: 0.8362 - val_loss: 0.6351 - val_accuracy: 0.8080
# Epoch 5/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.5068 - accuracy: 0.8642 - val_loss: 0.6172 - val_accuracy: 0.8126
# Epoch 6/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.4598 - accuracy: 0.8813 - val_loss: 0.6223 - val_accuracy: 0.8103
# Epoch 7/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.4233 - accuracy: 0.8930 - val_loss: 0.6236 - val_accuracy: 0.8164
# Epoch 8/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.3941 - accuracy: 0.9043 - val_loss: 0.6356 - val_accuracy: 0.8096
# Epoch 9/20
# 24/24 [==============================] - 2s 92ms/step - loss: 0.3692 - accuracy: 0.9120 - val_loss: 0.6472 - val_accuracy: 0.8179
# Epoch 10/20
# 24/24 [==============================] - 2s 78ms/step - loss: 0.3477 - accuracy: 0.9207 - val_loss: 0.6666 - val_accuracy: 0.8050
# Epoch 11/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.3296 - accuracy: 0.9275 - val_loss: 0.6733 - val_accuracy: 0.8042
# Epoch 12/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.3144 - accuracy: 0.9346 - val_loss: 0.6873 - val_accuracy: 0.7967
# Epoch 13/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.3005 - accuracy: 0.9395 - val_loss: 0.6946 - val_accuracy: 0.8103
# Epoch 14/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.2890 - accuracy: 0.9443 - val_loss: 0.7131 - val_accuracy: 0.7921
# Epoch 15/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.2767 - accuracy: 0.9478 - val_loss: 0.7181 - val_accuracy: 0.8111
# Epoch 16/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.2671 - accuracy: 0.9531 - val_loss: 0.7275 - val_accuracy: 0.8027
# Epoch 17/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.2573 - accuracy: 0.9551 - val_loss: 0.7435 - val_accuracy: 0.7967
# Epoch 18/20
# 24/24 [==============================] - 2s 82ms/step - loss: 0.2510 - accuracy: 0.9581 - val_loss: 0.7513 - val_accuracy: 0.7838
# Epoch 19/20
# 24/24 [==============================] - 2s 83ms/step - loss: 0.2410 - accuracy: 0.9637 - val_loss: 0.7610 - val_accuracy: 0.7989
# Epoch 20/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.2358 - accuracy: 0.9635 - val_loss: 0.7983 - val_accuracy: 0.7754
# Minimum validation loss reached in epoch 5

# %% [markdown]
# For the regularized model we notice that it starts overfitting in the same epoch as the baseline model. However, the loss increases much slower afterwards.

# %%
eval_metric(reg_model, reg_history, 'loss')

# %%
compare_models_by_metric(base_model, reg_model, base_history, reg_history, 'val_loss')

# %% [markdown]
# ## Question 1
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 1

# %%
#L1 Normalization

weights = [-5, 4, -3, 2, 1]

def l1_norm(weights):
    return sum(abs(w) for w in weights)

print(l1_norm(weights))
# Out:
# 15

# %% [markdown]
# ## Question 2
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||_2^2$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 2

# %%
#L2 Normalization

weights = [-5, 4, -3, 2, 1]

def l2_norm(weights):
    return np.sum(np.array(weights)**2)

print(l2_norm(weights))
# Out:
# 55

# %% [markdown]
# ## Adding dropout layers
# Add dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto.
#
# The intuitive explanation for dropout is that because individual nodes in the network cannot rely on the output of the others, each node must output features that are useful on their own.
#
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1].
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In `tf.keras` you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our network to see how well they do at reducing overfitting:

# %%
drop_model = models.Sequential()
drop_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(64, activation='relu'))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(3, activation='softmax'))
drop_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                640064
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
drop_history = deep_model(drop_model, X_train_rest, y_train_rest, X_valid, y_valid)
drop_min = optimal_epoch(drop_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 3s 104ms/step - loss: 0.8959 - accuracy: 0.6195 - val_loss: 0.7805 - val_accuracy: 0.6191
# Epoch 2/20
# 24/24 [==============================] - 2s 80ms/step - loss: 0.7294 - accuracy: 0.6519 - val_loss: 0.6895 - val_accuracy: 0.7124
# Epoch 3/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.6370 - accuracy: 0.7326 - val_loss: 0.6181 - val_accuracy: 0.7731
# Epoch 4/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.5625 - accuracy: 0.7928 - val_loss: 0.5763 - val_accuracy: 0.7830
# Epoch 5/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.4975 - accuracy: 0.8203 - val_loss: 0.5490 - val_accuracy: 0.7982
# Epoch 6/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.4464 - accuracy: 0.8426 - val_loss: 0.5333 - val_accuracy: 0.8050
# Epoch 7/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.4017 - accuracy: 0.8589 - val_loss: 0.5206 - val_accuracy: 0.8149
# Epoch 8/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.3732 - accuracy: 0.8715 - val_loss: 0.5255 - val_accuracy: 0.8088
# Epoch 9/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.3441 - accuracy: 0.8812 - val_loss: 0.5321 - val_accuracy: 0.8134
# Epoch 10/20
# 24/24 [==============================] - 2s 84ms/step - loss: 0.3144 - accuracy: 0.8941 - val_loss: 0.5432 - val_accuracy: 0.8118
# Epoch 11/20
# 24/24 [==============================] - 2s 82ms/step - loss: 0.2938 - accuracy: 0.9005 - val_loss: 0.5550 - val_accuracy: 0.8164
# Epoch 12/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.2657 - accuracy: 0.9118 - val_loss: 0.5645 - val_accuracy: 0.8202
# Epoch 13/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.2512 - accuracy: 0.9161 - val_loss: 0.5893 - val_accuracy: 0.8179
# Epoch 14/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.2327 - accuracy: 0.9223 - val_loss: 0.6014 - val_accuracy: 0.8164
# Epoch 15/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.2163 - accuracy: 0.9271 - val_loss: 0.6148 - val_accuracy: 0.8080
# Epoch 16/20
# 24/24 [==============================] - 3s 110ms/step - loss: 0.1985 - accuracy: 0.9304 - val_loss: 0.6237 - val_accuracy: 0.8073
# Epoch 17/20
# 24/24 [==============================] - 3s 119ms/step - loss: 0.1838 - accuracy: 0.9388 - val_loss: 0.6421 - val_accuracy: 0.8141
# Epoch 18/20
# 24/24 [==============================] - 3s 125ms/step - loss: 0.1756 - accuracy: 0.9416 - val_loss: 0.6602 - val_accuracy: 0.8073
# Epoch 19/20
# 24/24 [==============================] - 3s 130ms/step - loss: 0.1629 - accuracy: 0.9464 - val_loss: 0.6851 - val_accuracy: 0.8073
# Epoch 20/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.1527 - accuracy: 0.9491 - val_loss: 0.7021 - val_accuracy: 0.8096
# Minimum validation loss reached in epoch 7

# %%
eval_metric(drop_model, drop_history, 'loss')

# %% [markdown]
# The model with dropout layers starts overfitting later than the baseline model. The loss also increases slower than the baseline model.

# %%
compare_models_by_metric(base_model, drop_model, base_history, drop_history, 'val_loss')

# %% [markdown]
# The model with the Dropout layers starts overfitting later. Compared to the baseline model the loss also remains much lower.

# %% [markdown]
# ## Combined L2 + dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu', input_shape=(NB_WORDS,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3)
])

# %%
combined_history = deep_model(combined_model, X_train_rest, y_train_rest, X_valid, y_valid)
combined_min = optimal_epoch(combined_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 10s 375ms/step - loss: 1.8102 - accuracy: 0.5871 - val_loss: 1.0327 - val_accuracy: 0.6206
# Epoch 2/20
# 24/24 [==============================] - 8s 349ms/step - loss: 1.1190 - accuracy: 0.6833 - val_loss: 1.0392 - val_accuracy: 0.7185
# Epoch 3/20
# 24/24 [==============================] - 8s 318ms/step - loss: 5.2680 - accuracy: 0.7329 - val_loss: 10.4624 - val_accuracy: 0.6700
# Epoch 4/20
# 24/24 [==============================] - 8s 356ms/step - loss: 5.6648 - accuracy: 0.7414 - val_loss: 10.3473 - val_accuracy: 0.7557
# Epoch 5/20
# 24/24 [==============================] - 7s 302ms/step - loss: 7.8566 - accuracy: 0.7634 - val_loss: 3.4440 - val_accuracy: 0.7466
# Epoch 6/20
# 24/24 [==============================] - 8s 353ms/step - loss: 4.2676 - accuracy: 0.2378 - val_loss: 3.4174 - val_accuracy: 0.1753
# Epoch 7/20
# 24/24 [==============================] - 8s 356ms/step - loss: 7.3980 - accuracy: 0.1587 - val_loss: 10.6519 - val_accuracy: 0.1753
# Epoch 8/20
# 24/24 [==============================] - 7s 313ms/step - loss: 9.6320 - accuracy: 0.1587 - val_loss: 13.2018 - val_accuracy: 0.1753
# Epoch 9/20
# 24/24 [==============================] - 9s 359ms/step - loss: 11.0127 - accuracy: 0.1587 - val_loss: 13.5134 - val_accuracy: 0.1753
# Epoch 10/20
# 24/24 [==============================] - 8s 321ms/step - loss: 10.0110 - accuracy: 0.2396 - val_loss: 10.4380 - val_accuracy: 0.2807
# Epoch 11/20
# 24/24 [==============================] - 8s 333ms/step - loss: 8.5724 - accuracy: 0.2512 - val_loss: 9.5025 - val_accuracy: 0.2678
# Epoch 12/20
# 24/24 [==============================] - 10s 419ms/step - loss: 8.1818 - accuracy: 0.2419 - val_loss: 8.9705 - val_accuracy: 0.2276
# Epoch 13/20
# 24/24 [==============================] - 7s 298ms/step - loss: 6.8689 - accuracy: 0.2114 - val_loss: 3.0215 - val_accuracy: 0.1753
# Epoch 14/20
# 24/24 [==============================] - 8s 348ms/step - loss: 6.1126 - accuracy: 0.1587 - val_loss: 8.8251 - val_accuracy: 0.1753
# Epoch 15/20
# 24/24 [==============================] - 9s 357ms/step - loss: 8.1798 - accuracy: 0.1587 - val_loss: 12.3783 - val_accuracy: 0.1753
# Epoch 16/20
# 24/24 [==============================] - 7s 301ms/step - loss: 9.3990 - accuracy: 0.1587 - val_loss: 13.2656 - val_accuracy: 0.1753
# Epoch 17/20
# 24/24 [==============================] - 9s 357ms/step - loss: 10.6183 - accuracy: 0.1587 - val_loss: 13.3703 - val_accuracy: 0.1753
# Epoch 18/20
# 24/24 [==============================] - 8s 318ms/step - loss: 10.8631 - accuracy: 0.1587 - val_loss: 13.3773 - val_accuracy: 0.1753
# Epoch 19/20
# 24/24 [==============================] - 8s 330ms/step - loss: 10.9490 - accuracy: 0.1587 - val_loss: 13.3722 - val_accuracy: 0.1753
# Epoch 20/20
# 24/24 [==============================] - 9s 359ms/step - loss: 10.9889 - accuracy: 0.1587 - val_loss: 13.3550 - val_accuracy: 0.1753
# Minimum validation loss reached in epoch 1

# %%
eval_metric(combined_model, combined_history, 'loss')

# %%
compare_models_by_metric(base_model, combined_model, base_history, combined_history, 'val_loss')

# %% [markdown]
# ## Question 3
#
# When does it make sense to add both L2 regularization and Dropout?
#
# And what did doing so achieve in this case?

# %% [markdown]
# ### Answer 3
#
# Using both L2 regularization and Dropout is beneficial when dealing with complex models and high-dimensional datasets, as they target different aspects of overfitting and improve model robustness.

# %% [markdown]
# #Training on the full train data and evaluation on test data
# At first sight the reduced model seems to be the best model for generalization. But let's check that on the test set.

# %%
base_results = test_model(base_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, base_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 2s 89ms/step - loss: 0.1398 - accuracy: 0.9648
# Epoch 2/5
# 26/26 [==============================] - 2s 59ms/step - loss: 0.0980 - accuracy: 0.9737
# Epoch 3/5
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0784 - accuracy: 0.9787
# Epoch 4/5
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0649 - accuracy: 0.9820
# Epoch 5/5
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0563 - accuracy: 0.9838
# 46/46 [==============================] - 0s 4ms/step - loss: 0.9674 - accuracy: 0.7643
#
# Test accuracy: 76.43%

# %%
reduced_results = test_model(reduced_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reduced_min)
# Out:
# Epoch 1/15
# 26/26 [==============================] - 1s 32ms/step - loss: 0.2955 - accuracy: 0.9003
# Epoch 2/15
# 26/26 [==============================] - 1s 32ms/step - loss: 0.2845 - accuracy: 0.9036
# Epoch 3/15
# 26/26 [==============================] - 1s 31ms/step - loss: 0.2745 - accuracy: 0.9078
# Epoch 4/15
# 26/26 [==============================] - 1s 32ms/step - loss: 0.2651 - accuracy: 0.9105
# Epoch 5/15
# 26/26 [==============================] - 1s 43ms/step - loss: 0.2560 - accuracy: 0.9131
# Epoch 6/15
# 26/26 [==============================] - 1s 45ms/step - loss: 0.2479 - accuracy: 0.9179
# Epoch 7/15
# 26/26 [==============================] - 1s 43ms/step - loss: 0.2400 - accuracy: 0.9208
# Epoch 8/15
# 26/26 [==============================] - 1s 31ms/step - loss: 0.2326 - accuracy: 0.9226
# Epoch 9/15
# 26/26 [==============================] - 1s 31ms/step - loss: 0.2255 - accuracy: 0.9253
# Epoch 10/15
# 26/26 [==============================] - 1s 30ms/step - loss: 0.2187 - accuracy: 0.9278
# Epoch 11/15
# 26/26 [==============================] - 1s 31ms/step - loss: 0.2123 - accuracy: 0.9309
# Epoch 12/15
# 26/26 [==============================] - 1s 32ms/step - loss: 0.2063 - accuracy: 0.9324
# Epoch 13/15
# 26/26 [==============================] - 1s 31ms/step - loss: 0.2003 - accuracy: 0.9347
# Epoch 14/15
# 26/26 [==============================] - 1s 29ms/step - loss: 0.1946 - accuracy: 0.9370
# Epoch 15/15
# 26/26 [==============================] - 1s 29ms/step - loss: 0.1893 - accuracy: 0.9378
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5607 - accuracy: 0.7958
#
# Test accuracy: 79.58%

# %%
reg_results = test_model(reg_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reg_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 1s 53ms/step - loss: 0.2847 - accuracy: 0.9473
# Epoch 2/5
# 26/26 [==============================] - 1s 55ms/step - loss: 0.2592 - accuracy: 0.9545
# Epoch 3/5
# 26/26 [==============================] - 2s 87ms/step - loss: 0.2445 - accuracy: 0.9599
# Epoch 4/5
# 26/26 [==============================] - 2s 61ms/step - loss: 0.2358 - accuracy: 0.9624
# Epoch 5/5
# 26/26 [==============================] - 1s 49ms/step - loss: 0.2282 - accuracy: 0.9636
# 46/46 [==============================] - 0s 4ms/step - loss: 0.7610 - accuracy: 0.7814
#
# Test accuracy: 78.14%

# %%
drop_results = test_model(drop_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, drop_min)
# Out:
# Epoch 1/7
# 26/26 [==============================] - 1s 51ms/step - loss: 0.2039 - accuracy: 0.9392
# Epoch 2/7
# 26/26 [==============================] - 1s 53ms/step - loss: 0.1803 - accuracy: 0.9449
# Epoch 3/7
# 26/26 [==============================] - 1s 54ms/step - loss: 0.1636 - accuracy: 0.9510
# Epoch 4/7
# 26/26 [==============================] - 2s 77ms/step - loss: 0.1569 - accuracy: 0.9508
# Epoch 5/7
# 26/26 [==============================] - 2s 79ms/step - loss: 0.1455 - accuracy: 0.9554
# Epoch 6/7
# 26/26 [==============================] - 3s 105ms/step - loss: 0.1363 - accuracy: 0.9577
# Epoch 7/7
# 26/26 [==============================] - 2s 80ms/step - loss: 0.1301 - accuracy: 0.9595
# 46/46 [==============================] - 0s 4ms/step - loss: 0.7666 - accuracy: 0.7889
#
# Test accuracy: 78.89%

# %% [markdown]
# # Handling Underfitting
# * In a general situation, the best strategy is to increase the model complexity by either increasing the number of parameters of your deep learning model or the order of your model. Underfitting is due to the model being simpler than needed. It fails to capture the patterns in the data. Increasing the model complexity will lead to improvement in training performance. If we use a large enough model it can even achieve a training error of zero i.e. the model will memorize the data and suffer from over-fitting. The goal is to hit the optimal sweet spot.
# * Try to train the model for more epochs. Ensure that the loss is decreasing gradually over the course of the training. Otherwise, it is highly likely that there is some kind of bug or problem in the training code/logic itself.
# * If you aren’t shuffling the data after every epoch, it can harm the model performance. Ensuring that you are shuffling the data is a good check to perform at this point.

# %% [markdown]
# #Conclusion
# To recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# Two important approaches not covered in this guide are:
#
# * data-augmentation
# * batch normalization
#
# Remember that each method can help on its own, but often combining them can be even more effective.
#
# here are the ways to prevent underfitting
#
# * Get more training data.
# * Increase the size or number of parameters in the model.
# * Increase the complexity of the model.
# * Increasing the training time, until cost function is minimised.

# %% [markdown]
# # Bonus content - Visualizing L2 regularization

# %%
import numpy as np
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.core.debugger import set_trace
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
def plot_contour(f, x1bound, x2bound, resolution, ax):
    x1range = np.linspace(x1bound[0], x1bound[1], resolution)
    x2range = np.linspace(x2bound[0], x2bound[1], resolution)
    xg, yg = np.meshgrid(x1range, x2range)
    zg = np.zeros_like(xg)
    for i,j in itertools.product(range(resolution), range(resolution)):
        zg[i,j] = f([xg[i,j], yg[i,j]])
    ax.contour(xg, yg, zg, 100)
    return ax

# %% [markdown]
# Let's create a toy data:

# %%
N = 20
x = np.random.rand(N) * 10
y = -4*x + 10 + 2*np.random.randn(N)

# %% [markdown]
# visualize the regularized **cost function**

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l2_penalty = lambda w: np.dot(w,w)/2
cost_plus_l2 = lambda w: cost(w) + 5*l2_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l2_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L2 reg. $||w||_2^2$')
plot_contour(cost_plus_l2, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L2 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 1
#
# Plot the same for L1 regularization

# %% [markdown]
# ### Answer

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l1_penalty = lambda w: np.sum(np.abs(w))
cost_plus_l1 = lambda w: cost(w) + 5*l1_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||_2^2$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 2
# After looking at the visualization to what the L1 and L2 normalizations, how do they help while training?
#
#
# **L1 and L2 regularizations enhance training by adding a penalty to the loss function to curb overfitting. While L1 regularization aids in feature selection by zeroing out less important features, L2 regularization distributes weights among correlated features, preventing any single one from dominating the model.**

# %% [markdown]
# # Upload this Colab Notebook to your Github repository. Also add your *reflections* on today's learning in README.md
